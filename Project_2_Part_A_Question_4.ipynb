# %%
def intro():
    print("Hello World!")
    print("This program reads a set of 3 number from a list.")
    print("First we will check if the set of numbers is within the range of 0 to 100.")
    print("If the set is invalid, we will move on to next set.")
    print("If it's valid, we will compare those 3 number to see if any of those are same or not.")
    print("Following, we will round the number,\nE.g., 70-74 wiil be rounded down to 70 and 75-79 will be rounded up to 80.")
    print("Lastly, we will compare those numbers to each other again")
    print("Let's begin this program.\n")
    
def areTheyValid(m1, m2, m3):
    scores = [m1, m2, m3]
    valid = True
    for m in scores:
        if m < 0:
            valid = False
            print(f'{m} is not valid as it is less than 0.')
        elif m > 100:
            valid = False
            print(f'{m} is not valid as greater than 100.')
            
    return valid

def areTheySame(a1, a2, a3):
    if (a1 == a2 == a3):
        print("All three numbers are the same.")
    elif (a1 == a2 and a1 < a3) or (a1 == a3 and a1 < a2) or (a2 == a3 and a2 < a1):
        print("Two numbers are the same and the third is larger.")
    elif (a1 == a2 and a1 > a3) or (a1 == a3 and a1 > a2) or (a2 == a3 and a2 > a1):
        print("Two numbers are the same and the third is smaller.")
    else:
        print("All the numbers are different.")
        
def roundScore(n):
    n = round(n/10)
    return n * 10

def main():
    intro()
    total = 0
    count = 0
    notCount = 0
        
    num_list = [[55, 56, 57], [24, 44, 42], [98, 56, 58], [-10, 5, 67], [93, 22, 57],
               [34, 88, 120], [55, 55, 55], [68, 45, 93], [200, 35, 1], [62, 54, 62],
               [87, 125, 102], [8, 68, 75], [-5, 89, 115], [58, 99, 95], [2, 65, 85],
               [33, -33, 33], [84, 84, 81], [47, 80, 47], [7, 3, 6], [96, 39, 97]]
    for l in num_list:
        total += 1
        num1, num2, num3 = l[0], l[1], l[2]
        print(f'\nThe numbers are: {num1} {num2} {num3}.')
        validity = areTheyValid(num1, num2, num3)
        if validity == True:
            print("This set of numbers are valid.")
            count += 1
            samesies = areTheySame(num1, num2, num3)
            round1 = roundScore(num1)
            round2 = roundScore(num2)
            round3 = roundScore(num3)
            print(f'{num1} has been rounded to {round1}')
            print(f'{num2} has been rounded to {round2}')
            print(f'{num3} has been rounded to {round3}')
            roundSame = areTheySame(round1, round2, round3)
        else:
            notCount += 1
    print("\n\nThat is the end of the list.")
    print(f'\nTotal sets of number: {total}')
    print(f'Valid sets of number: {count}')
    print(f'Invalid sets of number: {notCount}')
    
main()
# Out:
# Hello World!
# This program reads a set of 3 number from a list.
# First we will check if the set of numbers is within the range of 0 to 100.
# If the set is invalid, we will move on to next set.
# If it's valid, we will compare those 3 number to see if any of those are same or not.
# Following, we will round the number,
# E.g., 70-74 wiil be rounded down to 70 and 75-79 will be rounded up to 80.
# Lastly, we will compare those numbers to each other again
# Let's begin this program.
#
#
# The numbers are: 55 56 57.
# This set of numbers are valid.
# All the numbers are different.
# 55 has been rounded to 60
# 56 has been rounded to 60
# 57 has been rounded to 60
# All three numbers are the same.
#
# The numbers are: 24 44 42.
# This set of numbers are valid.
# All the numbers are different.
# 24 has been rounded to 20
# 44 has been rounded to 40
# 42 has been rounded to 40
# Two numbers are the same and the third is smaller.
#
# The numbers are: 98 56 58.
# ...
