# %%
#Importing the libraries for the program
import pandas as pd

# %%
#named it df by using pandas to read the csv 
df= pd.read_csv('question2_data.csv',names=['Team','Wins','Loses','Draws'])

# %%
df
# Out:
#     Team  Wins  Loses  Draws
# 0   9867     4      2      3
# 1   1234     7      5      2
# 2   6213     9      7      0
# 3   1231    12      2      2
# 4   8821     2      7      7
# 5   1131     8      0      8
# 6   7761    10      3      3
# 7   6831     0     16      0
# 8   3131    16      0      0
# 9   3131     0      0     16
# 10  8424     0      0      0
# 11  4211     4      4      4

# %%
#In total there should only be 16 games 
total_games=16

# %%
for i in range(len(data)):
    #indexing the df so that it can know what to reference 
    team=df['Team'][i]
    print(f'Team: {team}')
    wins=df['Wins'][i]
    loses=df['Loses'][i]
    draws=df['Draws'][i]
    #priting the format desired
    print(f'{wins} Wins  {loses} Loses   {draws} Draws')
    #In total the wins and the loses and draws should total to 16 
    games_played= wins + loses + draws
    print(f'total number of games played is {games_played}')
    #This is how we check to see how many games are left 
    games_left=total_games-games_played
    #if statement for when there are no games left 
    if games_left == 0:
        print('The teams season is finished')
    #of not then the program will print the games remaining     
    else: 
        print(f'{games_left}: games still remaining')
    #average wins is on the bases of how many games were played not total games
    average_wins= wins/games_played
    print(f' The winning average is: {average_wins: .4f}')
    #if statements to determine the games were a tied or if they won 
    if(draws>wins):
        print('Number of games tied is greater than the number of games won')
    elif (draws<wins):
        print('Number of games tied is not greater than or equal to the number of games won')
    #if games tied is equal to games won
    else:
        print('Number of games tied is equal to the number of games won')
    #here to see if the draws were greater or less than the loses 
    if (draws>loses):
        print('number of games tied is greater than the number of games lost')
    elif (draws<loses):
        print('number of games tied is not greater than or equal to the number of games lost')
    else:
        print('number of games tied is equal to the number of games lost')
    
    #wip total
    wip_total = wins + draws - (3 * loses) 
    #an output of a negative number is not allowed 
    #let the output be 0
    if wip_total < 0:
        wip_total = 0
    # printing the wip total
    print(f'the wip total is {wip_total}')
  
    print()
# Out:
# Team: 9867
# 4 Wins  2 Loses   3 Draws
# total number of games played is 9
# 7: games still remaining
#  The winning average is:  0.4444
# Number of games tied is not greater than or equal to the number of games won
# number of games tied is greater than the number of games lost
# the wip total is 1
#
# Team: 1234
# 7 Wins  5 Loses   2 Draws
# total number of games played is 14
# 2: games still remaining
#  The winning average is:  0.5000
# Number of games tied is not greater than or equal to the number of games won
# number of games tied is not greater than or equal to the number of games lost
# the wip total is 0
#
# Team: 6213
# 9 Wins  7 Loses   0 Draws
# total number of games played is 16
# The teams season is finished
#  The winning average is:  0.5625
# Number of games tied is not greater than or equal to the number of games won
# number of games tied is not greater than or equal to the number of games lost
# the wip total is 0
#
# Team: 1231
# 12 Wins  2 Loses   2 Draws
# ...
